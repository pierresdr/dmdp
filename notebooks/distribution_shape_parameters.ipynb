# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot Settings
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='large')
plt.rc('ytick', labelsize='large')
plt.rc('axes', titlesize='x-large')
plt.rc('axes', labelsize='x-large')

# %% [markdown]
# ## LogNormal Simple Noise

# %%
shift = 1.0
mu, sigma = 0.0, 0.1
s = np.random.lognormal(mu, sigma, 1000) - shift
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')

x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x + shift) - mu)**2 / (2 * sigma**2)) / ((x + shift) * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_logns_dist.png')
plt.show()

# %% [markdown]
# ## LogNormal Noise

# %%
shift = 1.0
mu, sigma = 0.0, 1.0
s = np.random.lognormal(mu, sigma, 1000) - shift
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')

x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x + shift) - mu)**2 / (2 * sigma**2)) / ((x + shift) * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_logn_dist.png')
plt.show()

# %% [markdown]
# ## Triangular Noise

# %%
import matplotlib.pyplot as plt
import numpy as np

s = np.random.triangular(left=-2.0, mode=1.0, right=2.0, size=10000)
plt.hist(s, 100, density=True, align='mid')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_tri_dist.png')
plt.show()

# %% [markdown]
# ## Quadratic Beta(2,2) Noise

# %%
import matplotlib.pyplot as plt
import numpy as np

# Second parameter used:
# Shift, Scale, AB = 2.0, 2.0, 2.0
#

shift = 0.5
scale = 2.0
ab = 2.0

s = (np.random.beta(a=ab, b=ab, size=10000) - shift) * scale
plt.hist(s, 100, density=True, align='mid')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_quad_dist.png')
plt.show()

# %% [markdown]
# ## UShaped Noise

# %%
import matplotlib.pyplot as plt
import numpy as np

# First parameter used:
# Shift, Scale, AB = 0.5, 4.0, 0.5
# Too strong for either DET of MAF

# Second parameter used:
# Shift, Scale, AB = 0.5, 2.0, 0.5
#

shift = 0.5
scale = 2.0
ab = 0.5

s = (np.random.beta(a=ab, b=ab, size=10000) - shift) * scale
plt.hist(s, 100, density=True, align='mid')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_ush_dist.png')
plt.show()

# %% [markdown]
# ## Beta(8,2) Noise

# %%
import matplotlib.pyplot as plt
import numpy as np

shift = 0.5
scale = 2.0
a = 8
b = 2

s = (np.random.beta(a=a, b=b, size=10000) - shift) * scale
plt.hist(s, 100, density=True, align='mid')

plt.xlabel('Action Noise Values')
plt.axis('tight')
plt.xlim([-2.0, 2.0])
plt.savefig('./thesis_plots/noises_beta_dist.png')
plt.show()
