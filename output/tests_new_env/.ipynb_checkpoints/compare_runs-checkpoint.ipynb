# %%
import pandas as pd
import numpy as np
import os, json
import matplotlib.pyplot as plt
import torch

plt.rc('font', family='serif')
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')
plt.rc('axes', titlesize='x-large')
plt.rc('axes', labelsize='large')


table_color = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),
                (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),
                (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),
                (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
for i in range(len(table_color)):
        r, g, b = table_color[i]
        table_color[i] = (r / 255., g / 255., b / 255.)
        
pd.set_option('display.max_rows', 10)

# %%
def load_reward(path, algo='trpo'):
    files_name = os.listdir(path)
    files_name.remove('model_parameters.txt')
    models = list(filter(lambda n: "model" in n,  files_name))
    if len(models)==1:
        load_path = os.path.join(path, 'model.pt')
    else: 
        temp = np.array([int(name.replace('model_','').replace('.pt','')) for name in iter(models)])
        load_path = os.path.join(path, 'model_'+str(max(temp))+'.pt')
        
    ckpt = torch.load(load_path)
    
    if algo=='trpo':
        return ckpt['avg_reward'], ckpt['std_reward'], None
    else:
        return ckpt['avg_reward'], ckpt['std_reward'], ckpt['enc_losses']

def time_to_cv(r):
    temp = np.where(r>(-200))[0]
    if len(temp)==0:
        return len(r)
    else: 
        return temp[0]

# %%
cdir = r'C:\Users\pierr\Desktop\Polimi\delay_mdp\dmdp\output\tests_new_env'

# %%
env = 'Hopper_v2'
param = []
r_mean = []
r_std = []
enc_loss = []
for f in os.listdir(os.path.join(cdir,env)):
    print('Reading folder {}'.format(f))
    delay = f.split('_')[-1]
    algo = f.split('_')[0]
    if algo=='dtrpo':
        all_trains = [os.path.join(d,i) for d in os.listdir(os.path.join(cdir,env,f)) for i in os.listdir(os.path.join(cdir,env,f,d))]
        name_algo  = ['_'.join((algo,d)) for d in os.listdir(os.path.join(cdir,env,f)) for i in os.listdir(os.path.join(cdir,env,f,d))]
    else: 
        all_trains = os.listdir(os.path.join(cdir,env,f))
        name_algo = [algo for i in range(len(all_trains))]
    for d_i, d in enumerate(all_trains):
        assert os.path.exists(os.path.join(cdir,env,f,d,"model_parameters.txt")), 'empty folder'
        with open(os.path.join(cdir,env,f,d,'model_parameters.txt')) as file:
            param.append(json.loads(file.read())) 
        r_mean_, r_std_, enc_loss_ = load_reward(os.path.join(cdir,env,f,d),algo)
        param[-1]['r_mean'] = np.array(r_mean_)
        param[-1]['r_std'] = np.array(r_std_)
        param[-1]['enc_loss'] = np.array(enc_loss_)
        param[-1]['delay'] = delay
                
        param[-1]['algo'] = name_algo[d_i]
        
data = pd.DataFrame.from_dict(param)
# data['name'] = [i.split('/')[-1] for i in data['save_dir']]
data
# Out:
# Reading folder dtrpo_delay_5
# ['dtrpo_hd_16', 'dtrpo_hd_16', 'dtrpo_hd_16', 'dtrpo_hd_16', 'dtrpo_hd_32', 'dtrpo_hd_32', 'dtrpo_hd_32', 'dtrpo_hd_8', 'dtrpo_hd_8', 'dtrpo_hd_8', 'dtrpo_hd_8', 'dtrpo_hd_8', 'dtrpo_hd_8']
# Reading folder trpo_delay_0
# Reading folder trpo_delay_5
#      mode          env         seeds  curr_seed delay stochastic_delays  \
# 0   train  Walker2d-v2  [1, 2, 3, 4]          1     5             False
# 1   train  Walker2d-v2  [1, 2, 3, 4]          2     5             False
# 2   train  Walker2d-v2  [1, 2, 3, 4]          3     5             False
# 3   train  Walker2d-v2  [1, 2, 3, 4]          4     5             False
# 4   train  Walker2d-v2     [0, 1, 2]          0     5             False
# ..    ...          ...           ...        ...   ...               ...
# 15  train    Hopper-v2     [0, 1, 2]          2     0               NaN
# 16  train    Hopper-v2           [0]          0     5               NaN
# 17  train    Hopper-v2     [1, 2, 3]          1     5               NaN
# 18  train    Hopper-v2     [1, 2, 3]          2     5               NaN
# 19  train    Hopper-v2     [1, 2, 3]          3     5               NaN
#
#     max_delay  delay_proba  force_stoch_env use_belief  ...  hidden_dim_maf  \
# 0        50.0          0.7            False       True  ...            16.0
# 1        50.0          0.7            False       True  ...            16.0
# 2        50.0          0.7            False       True  ...            16.0
# 3        50.0          0.7            False       True  ...            16.0
# 4        50.0          0.7            False       True  ...            16.0
# ..        ...          ...              ...        ...  ...             ...
# 15        NaN          NaN            False        NaN  ...             NaN
# 16        NaN          NaN            False        NaN  ...             NaN
# 17        NaN          NaN            False        NaN  ...             NaN
# 18        NaN          NaN            False        NaN  ...             NaN
# 19        NaN          NaN            False        NaN  ...             NaN
#
#                                              save_dir  \
# 0                              ./output/new_env/dtrpo
# 1                              ./output/new_env/dtrpo
# 2                              ./output/new_env/dtrpo
# 3                              ./output/new_env/dtrpo
# 4                              ./output/new_env/dtrpo
# ..                                                ...
# 15                             ./output/new_env/tests
# 16  ./output/new_env/tests5/Hopper-v2-Results/Hopp...
# 17  ./output/new_env/tests5/Hopper-v2-Results/Hopp...
# 18  ./output/new_env/tests5/Hopper-v2-Results/Hopp...
# 19  ./output/new_env/tests5/Hopper-v2-Results/Hopp...
#
#                                                r_mean  \
# 0   [1.8342359678191948, 2.005966047852998, 1.8822...
# 1   [10.036354834834386, 9.395218351552144, 9.4812...
# 2   [0.35184812186351916, 1.3067210082218585, 1.28...
# 3   [-0.8282808064092424, -1.5518490522395887, -1....
# 4   [3.218434546044398, 2.4744759764790043, 3.1332...
# ..                                                ...
# 15  [22.160488021441893, 35.974733665726994, 44.79...
# 16  [51.54764843939885, 56.741856018232745, 58.027...
# 17  [17.01943776551219, 18.826211593460318, 26.944...
# 18  [15.233484378673376, 18.484384757239724, 20.34...
# 19  [21.277061442200687, 28.575085585319883, 35.55...
#
#                                                 r_std  \
# 0   [5.746561834464147, 5.995959028322313, 5.66301...
# 1   [12.85559636764638, 12.716746389073531, 12.306...
# 2   [4.722045026292645, 5.221656760134102, 5.37749...
# 3   [4.251901461653726, 4.147399190551667, 4.33975...
# 4   [7.136123425860872, 7.580110786975353, 7.27896...
# ..                                                ...
# 15  [19.80293271563122, 35.21693482035011, 39.5473...
# 16  [46.03274190540447, 49.89925660925608, 43.0103...
# 17  [14.755311954019964, 16.945335539155337, 35.27...
# 18  [9.790757434309304, 15.779746476385453, 19.177...
# 19  [18.398291198921374, 35.506404407388125, 40.85...
#
#                                              enc_loss         algo  \
# 0   [23.932207107543945, 23.903993606567383, 23.80...  dtrpo_hd_16
# 1   [24.215648651123047, 24.097352981567383, 24.02...  dtrpo_hd_16
# 2   [23.648332595825195, 23.492605209350586, 23.38...  dtrpo_hd_16
# 3   [23.551591873168945, 23.504610061645508, 23.46...  dtrpo_hd_16
# 4   [23.92481803894043, 24.165185928344727, 23.973...  dtrpo_hd_32
# ..                                                ...          ...
# 15                                               None         trpo
# 16                                               None         trpo
# 17                                               None         trpo
# 18                                               None         trpo
# 19                                               None         trpo
#
#     train_render  train_render_ep memoryless  test_epoch
# 0            NaN              NaN        NaN         NaN
# 1            NaN              NaN        NaN         NaN
# 2            NaN              NaN        NaN         NaN
# 3            NaN              NaN        NaN         NaN
# 4            NaN              NaN        NaN         NaN
# ..           ...              ...        ...         ...
# 15         False              1.0      False         0.0
# 16         False              1.0      False         0.0
# 17         False              1.0      False         0.0
# 18         False              1.0      False         0.0
# 19         False              1.0      False         0.0
#
# [20 rows x 67 columns]

# %%
fig = plt.figure(figsize=(16, 9))
fig.patch.set_facecolor('white')
ax = fig.add_subplot(1, 1, 1)
color = 0
for d_i, delay in enumerate(data['delay'].unique()):
    d_data = data[data['delay']==delay]
    print(d_data['algo'].unique())
    for a_i, algo in enumerate(d_data['algo'].unique()):
        a_data = d_data[d_data['algo']==algo]
        min_len = min([len(i) for i in a_data['r_mean']])
        r = np.stack([i[:min_len] for i in a_data['r_mean']])

        # Plot Range Settings
        r_avg = np.mean(r,axis=0)
        r_std = np.std(r,axis=0)
        epoch_ticks = np.arange(len(r_avg), step=50)
#         epoch_ticks =  np.array([int(i) for i in np.linspace(0,len(r_avg)-1,25)])

        # Plot Data
        ax.errorbar(epoch_ticks, r_avg[epoch_ticks], yerr=r_std[epoch_ticks], color=table_color[color], 
                    linewidth=1, ecolor='grey', elinewidth=1, capsize=1, label='_'.join((algo,delay)))
        color += 2

# Plot Decoration Settings
ax.legend(fontsize='medium',loc='upper left')
# ax.set_ylim(-2000, 0)
# ax.set_xticks(np.arange(0, 501, 100))
ax.set_title('Average reward on {}'.format(env))
ax.set_xlabel('Epochs')
ax.set_ylabel('Average Reward')
plt.grid()
# Out:
# ['dtrpo_hd_16' 'dtrpo_hd_32' 'dtrpo_hd_8' 'trpo']
# ['trpo']

# %%
env = 'Walker2d_v2'
param = []
r_mean = []
r_std = []
enc_loss = []
for f in os.listdir(os.path.join(cdir,env)):
    print('Reading folder {}'.format(f))
    delay = f.split('_')[-1]
    algo = f.split('_')[0]
    for d in os.listdir(os.path.join(cdir,env,f)):
        if os.path.exists(os.path.join(cdir,env,f,d,"model_parameters.txt")):
            with open(os.path.join(cdir,env,f,d,'model_parameters.txt')) as file:
                param.append(json.loads(file.read())) 
            r_mean_, r_std_, enc_loss_ = load_reward(os.path.join(cdir,env,f,d),algo)
            param[-1]['r_mean'] = np.array(r_mean_)
            param[-1]['r_std'] = np.array(r_std_)
            param[-1]['enc_loss'] = np.array(enc_loss_)
            param[-1]['delay'] = delay
            param[-1]['algo'] = algo
        
data = pd.DataFrame.from_dict(param)
# data['name'] = [i.split('/')[-1] for i in data['save_dir']]
data
# Out:
# Reading folder dtrpo_delay_5
# Reading folder trpo_delay_0
# Reading folder trpo_delay_5
#     mode          env delay         seeds  curr_seed  train_render  \
# 0  train  Walker2d-v2     0           [0]          0         False
# 1  train  Walker2d-v2     0  [1, 2, 3, 4]          1         False
# 2  train  Walker2d-v2     0  [1, 2, 3, 4]          2         False
# 3  train  Walker2d-v2     0  [1, 2, 3, 4]          3         False
# 4  train  Walker2d-v2     5           [0]          0         False
#
#    train_render_ep  force_stoch_env  stoch_mdp_param  memoryless  ...  \
# 0                1            False                1       False  ...
# 1                1            False                1       False  ...
# 2                1            False                1       False  ...
# 3                1            False                1       False  ...
# 4                1            False                1       False  ...
#
#    cg_iters  backtrack_iters  backtrack_coeff   lam  \
# 0        10               10              0.8  0.97
# 1        10               10              0.8  0.97
# 2        10               10              0.8  0.97
# 3        10               10              0.8  0.97
# 4        10               10              0.8  0.97
#
#                                             save_dir  save_period  \
# 0  ./output/new_env/tests0/Walker2d-v2-Results/Wa...          100
# 1  ./output/new_env/tests0/Walker2d-v2-Results/Wa...          100
# 2  ./output/new_env/tests0/Walker2d-v2-Results/Wa...          100
# 3  ./output/new_env/tests0/Walker2d-v2-Results/Wa...          100
# 4  ./output/new_env/tests5/Walker2d-v2-Results/Wa...          100
#
#                                               r_mean  \
# 0  [5.772607872568286, 4.233430737084882, 5.15299...
# 1  [1.362898031390017, 2.171231111889175, 3.02888...
# 2  [-7.022001831627209, -6.301660585427691, -5.66...
# 3  [-5.543726767001138, -4.798936694486388, -3.97...
# 4  [1.8169054299715794, 2.748657675881698, 2.8975...
#
#                                                r_std  enc_loss  algo
# 0  [16.089938890400365, 14.96437190532772, 12.385...      None  trpo
# 1  [3.14266010081642, 4.057124571446144, 5.014345...      None  trpo
# 2  [3.065218944270791, 3.258129071306811, 3.56983...      None  trpo
# 3  [3.4815614212533865, 3.657923305485381, 3.9620...      None  trpo
# 4  [4.737886871858549, 5.247640290200197, 5.15048...      None  trpo
#
# [5 rows x 37 columns]

# %%
fig = plt.figure(figsize=(16, 9))
fig.patch.set_facecolor('white')
ax = fig.add_subplot(1, 1, 1)
color = 0
for d_i, delay in enumerate(data['delay'].unique()):
    d_data = data[data['delay']==delay]
    for a_i, algo in enumerate(d_data['algo'].unique()):
        a_data = d_data[d_data['algo']==algo]
        min_len = min([len(i) for i in a_data['r_mean']])
        r = np.stack([i[:min_len] for i in a_data['r_mean']])

        # Plot Range Settings
        r_avg = np.mean(r,axis=0)
        r_std = np.std(r,axis=0)
        epoch_ticks = np.arange(len(r_avg), step=50)
#         epoch_ticks =  np.array([int(i) for i in np.linspace(0,len(r_avg)-1,25)])

        # Plot Data
        ax.errorbar(epoch_ticks, r_avg[epoch_ticks], yerr=r_std[epoch_ticks], color=table_color[color], 
                    linewidth=1, ecolor='grey', elinewidth=1, capsize=1, label='_'.join((algo,delay)))
        color += 2

# Plot Decoration Settings
ax.legend(fontsize='medium',loc='upper left')
# ax.set_ylim(-2000, 0)
# ax.set_xticks(np.arange(0, 501, 100))
ax.set_title('Average reward on {}'.format(env))
ax.set_xlabel('Epochs')
ax.set_ylabel('Average Reward')
plt.grid()

# %%
env = 'Reacher_v2'
param = []
r_mean = []
r_std = []
enc_loss = []
for f in os.listdir(os.path.join(cdir,env)):
    print('Reading folder {}'.format(f))
    delay = f.split('_')[-1]
    algo = f.split('_')[0]
    for d in os.listdir(os.path.join(cdir,env,f)):
        if os.path.exists(os.path.join(cdir,env,f,d,"model_parameters.txt")):
            with open(os.path.join(cdir,env,f,d,'model_parameters.txt')) as file:
                param.append(json.loads(file.read())) 
            r_mean_, r_std_, enc_loss_ = load_reward(os.path.join(cdir,env,f,d),algo)
            param[-1]['r_mean'] = np.array(r_mean_)
            param[-1]['r_std'] = np.array(r_std_)
            param[-1]['enc_loss'] = np.array(enc_loss_)
            param[-1]['delay'] = delay
            param[-1]['algo'] = algo
        
data = pd.DataFrame.from_dict(param)
# data['name'] = [i.split('/')[-1] for i in data['save_dir']]
data
# Out:
# Reading folder dtrpo_delay_5
# Reading folder trpo_delay_0
# Reading folder trpo_delay_5
#     mode         env  first_seed  n_seeds delay stochastic_delays  max_delay  \
# 0  train  Reacher-v2         0.0      1.0     5             False       50.0
# 1  train  Reacher-v2         NaN      NaN     0               NaN        NaN
# 2  train  Reacher-v2         NaN      NaN     5               NaN        NaN
#
#    delay_proba  force_stoch_env use_belief  ...  \
# 0          0.7            False      False  ...
# 1          NaN            False        NaN  ...
# 2          NaN            False        NaN  ...
#
#                                               r_mean  \
# 0  [-238.76231871152126, -247.19756220838818, -25...
# 1  [-934.7719149060296, -914.6405154849351, -855....
# 2  [-51.349770213608295, -49.702047422340414, -46...
#
#                                                r_std  \
# 0  [13.730101279774045, 14.730473468216559, 13.69...
# 1  [582.2697989652806, 616.7878877769618, 556.149...
# 2  [7.3468982086572145, 6.679358640711621, 6.4693...
#
#                                             enc_loss   algo  seeds  curr_seed  \
# 0  [73.88639068603516, 116.77127075195312, 149.58...  dtrpo    NaN        NaN
# 1                                               None   trpo    [0]        0.0
# 2                                               None   trpo    [0]        0.0
#
#    train_render  train_render_ep memoryless  test_epoch
# 0           NaN              NaN        NaN         NaN
# 1         False              1.0      False         0.0
# 2         False              1.0      False         0.0
#
# [3 rows x 69 columns]

# %%
fig = plt.figure(figsize=(16, 9))
fig.patch.set_facecolor('white')
ax = fig.add_subplot(1, 1, 1)
color = 0
for d_i, delay in enumerate(data['delay'].unique()):
    d_data = data[data['delay']==delay]
    for a_i, algo in enumerate(d_data['algo'].unique()):
        a_data = d_data[d_data['algo']==algo]
        min_len = min([len(i) for i in a_data['r_mean']])
        r = np.stack([i[:min_len] for i in a_data['r_mean']])

        # Plot Range Settings
        r_avg = np.mean(r,axis=0)
        r_std = np.std(r,axis=0)
        epoch_ticks = np.arange(len(r_avg), step=50)
#         epoch_ticks =  np.array([int(i) for i in np.linspace(0,len(r_avg)-1,25)])

        # Plot Data
        ax.errorbar(epoch_ticks, r_avg[epoch_ticks], yerr=r_std[epoch_ticks], color=table_color[color], 
                    linewidth=1, ecolor='grey', elinewidth=1, capsize=1, label='_'.join((algo,delay)))
        color += 2

# Plot Decoration Settings
ax.legend(fontsize='medium',loc='upper left')
# ax.set_ylim(-2000, 0)
# ax.set_xticks(np.arange(0, 501, 100))
ax.set_title('Average reward on {}'.format(env))
ax.set_xlabel('Epochs')
ax.set_ylabel('Average Reward')
plt.grid()
