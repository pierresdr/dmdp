# %%
import pandas as pd
import numpy as np
import os, json
import matplotlib.pyplot as plt
import torch

# %%
def load_reward(path):
    files_name = os.listdir(path)
    files_name.remove('model_parameters.txt')
    models = list(filter(lambda n: "model" in n,  files_name))
    if len(models)==1:
        load_path = os.path.join(path, 'model.pt')
    else: 
        temp = np.array([int(name.replace('model_','').replace('.pt','')) for name in iter(models)])
        load_path = os.path.join(path, 'model_'+str(max(temp))+'.pt')
        
    ckpt = torch.load(load_path)
    
    return ckpt['avg_reward'], ckpt['std_reward'], ckpt['enc_losses']

# %%
param = []
r_mean = []
r_std = []
enc_loss = []
for d in filter(lambda x:'Pendulum' in x,os.listdir(os.getcwd())):
    if os.path.exists(os.path.join(d,"model_parameters.txt")):
        with open(os.path.join(d,'model_parameters.txt')) as f:
            param.append(json.loads(f.read()))
        r_mean_, r_std_, enc_loss_ = load_reward(d)
        param[-1]['r_mean'] = np.array(r_mean_)
        param[-1]['r_std'] = np.array(r_std_)
        param[-1]['enc_loss'] = np.array(enc_loss_)
        
data = pd.DataFrame.from_dict(param)
data['name'] = [i.split('/')[-1] for i in data['save_dir']]

# %%
pd.set_option('display.max_columns', None)
data
# Out:
#     mode          env  seed  delay  stochastic_delays  max_delay  delay_proba  \
# 0  train     Pendulum     0      5              False         50          0.7
# 1  train     Pendulum     0      5              False         50          0.7
# 2  train  Pendulum-v0     0      5              False         50          0.7
# 3  train  Pendulum-v0     0      5              False         50          0.7
#
#    force_stoch_env  steps_per_epoch  epochs  max_ep_len  gamma  delta  \
# 0             True             5000    1000         250   0.99  0.001
# 1             True             5000    1000         250   0.99  0.001
# 2            False             5000    1000         250   0.99  0.001
# 3            False             5000    1000         250   0.99  0.001
#
#    save_period  train_continue  test_episodes  test_steps epoch_load  v_hid  \
# 0          100           False             10         250       None     64
# 1          100           False             10         250       None     64
# 2          100           False             10         250       None     64
# 3          100           False             10         250       None     64
#
#    v_l  vf_lr  v_iters pi_activation  pi_hid  pi_l  damping_coeff  cg_iters  \
# 0    1   0.01        3       nn.ReLU      64     2            0.1        10
# 1    1   0.01        3       nn.ReLU      64     2            0.1        10
# 2    1   0.01        3       nn.ReLU      64     2            0.1        10
# 3    1   0.01        3       nn.ReLU      64     2            0.1        10
#
#    backtrack_iters  backtrack_coeff   lam  pretrain_epochs  \
# 0               10              0.8  0.97                2
# 1               10              0.8  0.97                2
# 2               10              0.8  0.97                2
# 3               10              0.8  0.97                2
#
#    epochs_belief_training  pretrain_steps  train_enc_iters  size_pred_buf  \
# 0                     300           10000                1         100000
# 1                     200           10000                1         100000
# 2                      10           10000                1         100000
# 3                     100           10000                1         100000
#
#    batch_size_pred  enc_lr  maf_lr  enc_dim  enc_heads  enc_l  enc_ff  \
# 0            10000    0.01    0.01       64          2      1       8
# 1            10000    0.01    0.01       64          2      1       8
# 2            10000    0.01    0.01       64          2      1       8
# 3            10000    0.01    0.01       64          2      1       8
#
#    enc_rescaling  enc_causal  enc_pred_to_pi  only_last_belief  convolutions  \
# 0          False        True           False             False         False
# 1          False        True           False             False         False
# 2          False        True           False             False         False
# 3          False        True           False             False         False
#
#     lstm  n_layers  hidden_size  n_blocks_maf  hidden_dim  hidden_dim_maf  \
# 0  False         3           16             5           4              16
# 1  False         3           16             5           4              16
# 2  False         3           16             5           4              16
# 3  False         3           16             5           4              16
#
#                                             save_dir  \
# 0     ./output/dtrpo/Pendulum-Results/Pendulum-run29
# 1     ./output/dtrpo/Pendulum-Results/Pendulum-run30
# 2  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 3  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
#
#                                               r_mean use_belief  \
# 0  [-1208.5128296700304, -1181.747691613433, -123...        NaN
# 1  [-1213.8365517391264, -1142.9042167583038, -11...        NaN
# 2  [-1639.55752581564, -1453.5511078864076, -1441...       True
# 3  [-1639.55752581564, -1453.5511078864076, -1441...       True
#
#    stoch_mdp_param stoch_mdp_distrib                               name  \
# 0              NaN               NaN                     Pendulum-run29
# 1              NaN               NaN                     Pendulum-run30
# 2              1.0          Gaussian  Pendulum-v0-20-12-20_22_28_671999
# 3              1.0          Gaussian  Pendulum-v0-20-12-20_22_29_300169
#
#    max_mean_r  argmax_mean_r
# 0 -131.527536            998
# 1 -130.418658            849
# 2 -852.762749            968
# 3 -198.441099            957

# %%
print('Different columns: \n')
for c in data.columns:
    a = data[c].values
    if not (a[0] == a).all():
        print('\t -  '+c+'\n')
# Out:
# Different columns:
#
# 	 -  env
#
# 	 -  force_stoch_env
#
# 	 -  epochs_belief_training
#
# 	 -  save_dir
#
# 	 -  use_belief
#
# 	 -  stoch_mdp_param
#
# 	 -  stoch_mdp_distrib
#
# 	 -  name

# %%
for i, r in enumerate(data['r_mean']):
    m = np.argmax(r)
    print('{0:<40} - Max mean reward {1:<20} -  at epoch {2}'.format(data['name'][i],r[m],m))
    
data['max_mean_r'] = [max(r) for r in data['r_mean']]
data['argmax_mean_r'] = [r[np.array(r)<(-200)] for r in data['r_mean']]
# Out:
# Pendulum-run29                           - Max mean reward -131.52753616798216  -  at epoch 998
# Pendulum-run30                           - Max mean reward -130.4186578321732   -  at epoch 849
# Pendulum-v0-20-12-20_22_28_671999        - Max mean reward -852.7627485323059   -  at epoch 968
# Pendulum-v0-20-12-20_22_29_300169        - Max mean reward -198.4410992828016   -  at epoch 957
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-728587e7bf39> in <module>
#       4
#       5 data['max_mean_r'] = [max(r) for r in data['r_mean']]
# ----> 6 data['argmax_mean_r'] = [r[np.array(r)<(-200)] for r in data['r_mean']]
#
# <ipython-input-55-728587e7bf39> in <listcomp>(.0)
#       4
#       5 data['max_mean_r'] = [max(r) for r in data['r_mean']]
# ----> 6 data['argmax_mean_r'] = [r[np.array(r)<(-200)] for r in data['r_mean']]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
plt.scatter(data['max_mean_r'],data['enc_lr'])
# Out:
# Pendulum-run29                           - Max mean reward -131.52753616798216  -  at epoch 998
# Pendulum-run30                           - Max mean reward -130.4186578321732   -  at epoch 849
# Pendulum-v0-20-12-20_22_28_671999        - Max mean reward -852.7627485323059   -  at epoch 968
# Pendulum-v0-20-12-20_22_29_300169        - Max mean reward -198.4410992828016   -  at epoch 957
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'r_std'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-cf4bc3ab5269> in <module>
#       3     print('{0:<40} - Max mean reward {1:<20} -  at epoch {2}'.format(data['name'][i],r[m],m))
#       4
# ----> 5 data['max_std_r'] = [max(r) for r in data['r_std']]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'r_std'
