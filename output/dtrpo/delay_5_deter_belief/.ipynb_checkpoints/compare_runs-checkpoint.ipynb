# %%
import pandas as pd
import numpy as np
import os, json
import matplotlib.pyplot as plt
import torch

# %%
def load_reward(path):
    files_name = os.listdir(path)
    files_name.remove('model_parameters.txt')
    models = list(filter(lambda n: "model" in n,  files_name))
    if len(models)==1:
        load_path = os.path.join(path, 'model.pt')
    else: 
        temp = np.array([int(name.replace('model_','').replace('.pt','')) for name in iter(models)])
        load_path = os.path.join(path, 'model_'+str(max(temp))+'.pt')
        
    ckpt = torch.load(load_path)
    
    return ckpt['avg_reward'], ckpt['std_reward'], ckpt['enc_losses']

def time_to_cv(r):
    temp = np.where(r>(-200))[0]
    if len(temp)==0:
        return len(r)
    else: 
        return temp[0]

# %%
param = []
r_mean = []
r_std = []
enc_loss = []
for d in filter(lambda x:'Pendulum' in x,os.listdir(os.getcwd())):
    if os.path.exists(os.path.join(d,"model_parameters.txt")):
        with open(os.path.join(d,'model_parameters.txt')) as f:
            param.append(json.loads(f.read()))
        r_mean_, r_std_, enc_loss_ = load_reward(d)
        param[-1]['r_mean'] = np.array(r_mean_)
        param[-1]['r_std'] = np.array(r_std_)
        param[-1]['enc_loss'] = np.array(enc_loss_)
        
data = pd.DataFrame.from_dict(param)
data['name'] = [i.split('/')[-1] for i in data['save_dir']]

# %%
pd.set_option('display.max_columns', None)
data
# Out:
#      mode          env  seed  delay  stochastic_delays  max_delay  \
# 0   train     Pendulum     0      5              False         50
# 1   train     Pendulum     0      5              False         50
# 2   train  Pendulum-v0     0      5              False         50
# 3   train  Pendulum-v0     0      5              False         50
# 4   train  Pendulum-v0     0      5              False         50
# 5   train  Pendulum-v0     0      5              False         50
# 6   train  Pendulum-v0     0      5              False         50
# 7   train  Pendulum-v0     0      5              False         50
# 8   train  Pendulum-v0     0      5              False         50
# 9   train  Pendulum-v0     0      5              False         50
# 10  train  Pendulum-v0     0      5              False         50
# 11  train  Pendulum-v0     1      5              False         50
#
#     delay_proba  force_stoch_env  steps_per_epoch  epochs  max_ep_len  gamma  \
# 0           0.7             True             5000    1000         250   0.99
# 1           0.7             True             5000    1000         250   0.99
# 2           0.7            False             5000    1000         250   0.99
# 3           0.7            False             5000    1000         250   0.99
# 4           0.7            False             5000    1000         250   0.99
# 5           0.7            False             5000    1000         250   0.99
# 6           0.7            False             5000    1000         250   0.99
# 7           0.7            False             5000    1000         250   0.99
# 8           0.7            False             5000    1000         250   0.99
# 9           0.7            False             5000    1000         250   0.99
# 10          0.7            False             5000    1000         250   0.99
# 11          0.7            False             5000    1000         250   0.99
#
#     delta  save_period  train_continue  test_episodes  test_steps epoch_load  \
# 0   0.001          100           False             10         250       None
# 1   0.001          100           False             10         250       None
# 2   0.001          100           False             10         250       None
# 3   0.001          100           False             10         250       None
# 4   0.001          100           False             10         250       None
# 5   0.001          100           False             10         250       None
# 6   0.001          100           False             10         250       None
# 7   0.001          100           False             10         250       None
# 8   0.001          100           False             10         250       None
# 9   0.001          100           False             10         250       None
# 10  0.001          100           False             10         250       None
# 11  0.001          100           False             10         250       None
#
#     v_hid  v_l  vf_lr  v_iters pi_activation  pi_hid  pi_l  damping_coeff  \
# 0      64    1   0.01        3       nn.ReLU      64     2            0.1
# 1      64    1   0.01        3       nn.ReLU      64     2            0.1
# 2      64    1   0.01        3       nn.ReLU      64     2            0.1
# 3      64    1   0.01        3       nn.ReLU      64     2            0.1
# 4      64    1   0.01        3       nn.ReLU      64     2            0.1
# 5      64    1   0.01        3       nn.ReLU      64     2            0.1
# 6      64    1   0.01        3       nn.ReLU      64     2            0.1
# 7      64    1   0.01        3       nn.ReLU      64     2            0.1
# 8      64    1   0.01        3       nn.ReLU      64     2            0.1
# 9      64    1   0.01        3       nn.ReLU      64     2            0.1
# 10     64    1   0.01        3       nn.ReLU      64     2            0.1
# 11     64    1   0.01        3       nn.ReLU      64     2            0.1
#
#     cg_iters  backtrack_iters  backtrack_coeff   lam  pretrain_epochs  \
# 0         10               10              0.8  0.97                2
# 1         10               10              0.8  0.97                2
# 2         10               10              0.8  0.97                2
# 3         10               10              0.8  0.97                2
# 4         10               10              0.8  0.97                2
# 5         10               10              0.8  0.97                2
# 6         10               10              0.8  0.97                2
# 7         10               10              0.8  0.97                2
# 8         10               10              0.8  0.97                2
# 9         10               10              0.8  0.97                2
# 10        10               10              0.8  0.97                2
# 11        10               10              0.8  0.97                2
#
#     epochs_belief_training  pretrain_steps  train_enc_iters  size_pred_buf  \
# 0                      300           10000                1         100000
# 1                      200           10000                1         100000
# 2                       10           10000                1         100000
# 3                      100           10000                1         100000
# 4                      250           10000                1         100000
# 5                      150           10000                1         100000
# 6                       50           10000                1         100000
# 7                      350           10000                1         100000
# 8                      350           10000                2         100000
# 9                      200           10000                2         100000
# 10                     200           10000                4         100000
# 11                     200           10000                2         100000
#
#     batch_size_pred  enc_lr  maf_lr  enc_dim  enc_heads  enc_l  enc_ff  \
# 0             10000    0.01    0.01       64          2      1       8
# 1             10000    0.01    0.01       64          2      1       8
# 2             10000    0.01    0.01       64          2      1       8
# 3             10000    0.01    0.01       64          2      1       8
# 4             10000    0.01    0.01       64          2      1       8
# 5             10000    0.01    0.01       64          2      1       8
# 6             10000    0.01    0.01       64          2      1       8
# 7             10000    0.01    0.01       64          2      1       8
# 8             10000    0.01    0.01       64          2      1       8
# 9             10000    0.01    0.01       64          2      1       8
# 10            10000    0.01    0.01       64          2      1       8
# 11            10000    0.01    0.01       64          2      1       8
#
#     enc_rescaling  enc_causal  enc_pred_to_pi  only_last_belief  convolutions  \
# 0           False        True           False             False         False
# 1           False        True           False             False         False
# 2           False        True           False             False         False
# 3           False        True           False             False         False
# 4           False        True           False             False         False
# 5           False        True           False             False         False
# 6           False        True           False             False         False
# 7           False        True           False             False         False
# 8           False        True           False             False         False
# 9           False        True           False             False         False
# 10          False        True           False             False         False
# 11          False        True           False             False         False
#
#      lstm  n_layers  hidden_size  n_blocks_maf  hidden_dim  hidden_dim_maf  \
# 0   False         3           16             5           4              16
# 1   False         3           16             5           4              16
# 2   False         3           16             5           4              16
# 3   False         3           16             5           4              16
# 4   False         3           16             5           4              16
# 5   False         3           16             5           4              16
# 6   False         3           16             5           4              16
# 7   False         3           16             5           4              16
# 8   False         3           16             5           4              16
# 9   False         3           16             5           4              16
# 10  False         3           16             5           4              16
# 11  False         3           16             5           8              16
#
#                                              save_dir  \
# 0      ./output/dtrpo/Pendulum-Results/Pendulum-run29
# 1      ./output/dtrpo/Pendulum-Results/Pendulum-run30
# 2   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 3   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 4   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 5   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 6   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 7   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 8   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 9   ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 10  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 11  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
#
#                                                r_mean  \
# 0   [-1208.5128296700304, -1181.747691613433, -123...
# 1   [-1213.8365517391264, -1142.9042167583038, -11...
# 2   [-1639.55752581564, -1453.5511078864076, -1441...
# 3   [-1639.55752581564, -1453.5511078864076, -1441...
# 4   [-1639.55752581564, -1453.5511929018564, -1441...
# 5   [-1639.55752581564, -1453.5513557770153, -1441...
# 6   [-1639.55752581564, -1453.5513243204996, -1441...
# 7   [-1639.55752581564, -1453.5511078864076, -1441...
# 8   [-1639.55752581564, -1471.5262617944184, -1486...
# 9   [-1639.55752581564, -1478.5796834925181, -1484...
# 10  [-1639.55752581564, -1496.4526972469337, -1457...
# 11  [-1519.0709472339759, -1561.1739212921443, -17...
#
#                                                 r_std  \
# 0   [313.88580114515736, 289.7628214862086, 329.25...
# 1   [322.6190178397965, 247.7275026762929, 301.584...
# 2   [455.6207451659447, 404.23946735231544, 338.93...
# 3   [455.6207451659447, 404.23946735231544, 338.93...
# 4   [455.6207451659447, 404.2393611197558, 338.930...
# 5   [455.6207451659447, 404.2391470300242, 338.936...
# 6   [455.6207451659447, 404.23919488686255, 338.93...
# 7   [455.6207451659447, 404.23946735231544, 338.93...
# 8   [455.6207451659447, 380.9707026694791, 353.677...
# 9   [455.6207451659447, 373.55335947877205, 354.77...
# 10  [455.6207451659447, 400.48868876646213, 347.14...
# 11  [289.1276829723665, 357.3008957923836, 300.044...
#
#                                              enc_loss use_belief  \
# 0   [4.7381062507629395, 4.67898416519165, 4.58821...        NaN
# 1   [4.738399505615234, 4.674805164337158, 4.61855...        NaN
# 2   [4.4928297996521, 4.555641174316406, 4.5622549...       True
# 3   [4.4928297996521, 4.555641174316406, 4.5622549...       True
# 4   [4.4928297996521, 4.555640697479248, 4.5622549...       True
# 5   [4.4928297996521, 4.555641174316406, 4.5622515...       True
# 6   [4.4928297996521, 4.555640697479248, 4.5622539...       True
# 7   [4.4928297996521, 4.555641174316406, 4.5622549...       True
# 8   [4.420820236206055, 4.471180438995361, 4.43625...       True
# 9   [4.415775775909424, 4.46915864944458, 4.421768...       True
# 10  [4.317436218261719, 4.3103108406066895, 4.2660...       True
# 11  [4.589354515075684, 4.4735846519470215, 4.3105...       True
#
#     stoch_mdp_param stoch_mdp_distrib                               name  \
# 0               NaN               NaN                     Pendulum-run29
# 1               NaN               NaN                     Pendulum-run30
# 2               1.0          Gaussian  Pendulum-v0-20-12-20_22_28_671999
# 3               1.0          Gaussian  Pendulum-v0-20-12-20_22_29_300169
# 4               1.0          Gaussian  Pendulum-v0-20-12-22_23_26_870356
# 5               1.0          Gaussian  Pendulum-v0-20-12-22_23_27_921213
# 6               1.0          Gaussian  Pendulum-v0-20-12-22_23_29_341327
# 7               1.0          Gaussian  Pendulum-v0-20-12-22_23_29_866179
# 8               1.0          Gaussian  Pendulum-v0-20-12-23_12_04_084702
# 9               1.0          Gaussian  Pendulum-v0-20-12-23_16_45_877646
# 10              1.0          Gaussian  Pendulum-v0-20-12-23_22_42_527094
# 11              1.0          Gaussian  Pendulum-v0-20-12-24_13_31_743825
#
#     max_mean_r  min_enc_loss  cv_speed
# 0  -131.527536     -3.353540       754
# 1  -130.418658     -1.457485       599
# 2  -852.762749      4.318354      1000
# 3  -198.441099      0.956439       957
# 4  -132.737451     -2.062485       487
# 5  -166.846108     -0.469375       648
# 6  -760.849469      3.486502      1000
# 7  -114.284765     -3.170458       549
# 8  -193.791794     -3.541979       967
# 9  -113.079759     -3.835572       417
# 10 -111.849865     -4.725924       417
# 11 -119.720292     -3.843304       267

# %%
print('Different columns: \n')
for c in data.columns:
    a = data[c].values
    if not (a[0] == a).all():
        print('\t -  '+c+'\n')
# Out:
# Different columns:
#
# 	 -  env
#
# 	 -  force_stoch_env
#
# 	 -  epochs_belief_training
#
# 	 -  train_enc_iters
#
# 	 -  save_dir
# C:\Users\pierr\Anaconda3\envs\dmdp\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-3b21f94faf42> in <module>
#       2 for c in data.columns:
#       3     a = data[c].values
# ----> 4     if not (a[0] == a).all():
#       5         print('\t -  '+c+'\n')
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
for i, r in enumerate(data['r_mean']):
    m = np.argmax(r)
    print('{0:<40} - Max mean reward {1:<20} -  at epoch {2}'.format(data['name'][i],r[m],m))
    
data['max_mean_r'] = [max(r) for r in data['r_mean']]
data['min_enc_loss'] = [min(r) for r in data['enc_loss']]
data['cv_speed'] = [time_to_cv(r) for r in data['r_mean']]
# Out:
# Pendulum-run29                           - Max mean reward -131.52753616798216  -  at epoch 998
# Pendulum-run30                           - Max mean reward -130.4186578321732   -  at epoch 849
# Pendulum-v0-20-12-20_22_28_671999        - Max mean reward -852.7627485323059   -  at epoch 968
# Pendulum-v0-20-12-20_22_29_300169        - Max mean reward -198.4410992828016   -  at epoch 957
# Pendulum-v0-20-12-22_23_26_870356        - Max mean reward -132.73745107446905  -  at epoch 967
# Pendulum-v0-20-12-22_23_27_921213        - Max mean reward -166.84610804595692  -  at epoch 898
# Pendulum-v0-20-12-22_23_29_341327        - Max mean reward -760.8494686528602   -  at epoch 961
# Pendulum-v0-20-12-22_23_29_866179        - Max mean reward -114.28476483979996  -  at epoch 775
# Pendulum-v0-20-12-23_12_04_084702        - Max mean reward -193.79179447908345  -  at epoch 967
# Pendulum-v0-20-12-23_16_45_877646        - Max mean reward -113.07975907341844  -  at epoch 775
# Pendulum-v0-20-12-23_22_42_527094        - Max mean reward -111.84986522202419  -  at epoch 775
# Pendulum-v0-20-12-24_13_31_743825        - Max mean reward -119.72029181418316  -  at epoch 978

# %%
plt.scatter(data['epochs_belief_training'], data['cv_speed'])

# %%
fig, ax = plt.subplots()
plt.scatter(data['epochs_belief_training'], data['min_enc_loss'])
for i in range(len(data)):
    ax.annotate(i, (data['epochs_belief_training'][i], data['min_enc_loss'][i]))
