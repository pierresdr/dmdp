# %%
import pandas as pd
import numpy as np
import os, json

# %%
param = []
for d in filter(lambda x:'Pendulum-run' in x,os.listdir(os.getcwd())):
    with open(os.path.join(d,'model_parameters.txt')) as f:
        param.append(json.loads(f.read()))

# %%
pd.set_option('display.max_columns', None)
data = pd.DataFrame.from_dict(param)
data
# Out:
#     mode       env  seed  delay  stochastic_delays  max_delay  delay_proba  \
# 0  train  Pendulum     0      3              False         50          0.7
# 1  train  Pendulum     0      3              False         50          0.7
# 2  train  Pendulum     0      3              False         50          0.7
#
#    force_stoch_env  steps_per_epoch  epochs  max_ep_len  gamma  delta  \
# 0             True             5000    1000         250   0.99  0.001
# 1             True             5000    1000         250   0.99  0.001
# 2             True             5000    1000         250   0.99  0.001
#
#    train_continue  test_episodes  test_steps epoch_load  v_hid  v_l  vf_lr  \
# 0           False             10         250       None     64    1   0.01
# 1           False             10         250       None     64    1   0.01
# 2           False             10         250       None     64    1   0.01
#
#    v_iters pi_activation  pi_hid  pi_l  damping_coeff  cg_iters  \
# 0        3       nn.ReLU      64     2            0.1        10
# 1        3       nn.ReLU      64     2            0.1        10
# 2        3       nn.ReLU      64     2            0.1        10
#
#    backtrack_iters  backtrack_coeff   lam  pretrain_epochs  pretrain_steps  \
# 0               10              0.8  0.97                2           10000
# 1               10              0.8  0.97                2           10000
# 2               10              0.8  0.97                2           10000
#
#    train_enc_iters  size_pred_buf  batch_size_pred  enc_lr  maf_lr  enc_dim  \
# 0                1         100000            10000   0.005   0.005       64
# 1                1         100000             1000   0.050   0.005       32
# 2                1         500000             5000   0.005   0.005       32
#
#    enc_heads  enc_l  enc_ff  enc_rescaling  enc_causal  enc_training  \
# 0          2      1       8          False        True         False
# 1          2      1       8          False        True         False
# 2          2      1       8          False        True         False
#
#    enc_pred_to_pi  only_last_belief  convolutions   lstm  n_layers  \
# 0           False             False         False  False         3
# 1           False             False         False  False         3
# 2           False             False         False  False         3
#
#    hidden_size  n_blocks_maf  hidden_dim  hidden_dim_maf  \
# 0           16             5           8              16
# 1           16             5           8              16
# 2           16             5           8              16
#
#                                         save_dir
# 0  ./output/dtrpo/Pendulum-Results/Pendulum-run1
# 1  ./output/dtrpo/Pendulum-Results/Pendulum-run2
# 2  ./output/dtrpo/Pendulum-Results/Pendulum-run4

# %%
print('Different columns: \n')
for c in data.columns:
    a = data[c].values
    if not (a[0] == a).all():
        print('\t -  '+c+'\n')
# Out:
# Different columns:
#
# 	 -  size_pred_buf
#
# 	 -  batch_size_pred
#
# 	 -  enc_lr
#
# 	 -  enc_dim
#
# 	 -  save_dir
