# %%
import pandas as pd
import numpy as np
import os, json
import matplotlib.pyplot as plt
import torch

# %%
def load_reward(path):
    files_name = os.listdir(path)
    files_name.remove('model_parameters.txt')
    models = list(filter(lambda n: "model" in n,  files_name))
    if len(models)==1:
        load_path = os.path.join(path, 'model.pt')
    else: 
        temp = np.array([int(name.replace('model_','').replace('.pt','')) for name in iter(models)])
        load_path = os.path.join(path, 'model_'+str(max(temp))+'.pt')
        
    ckpt = torch.load(load_path)
    
    return ckpt['avg_reward'], ckpt['std_reward'], ckpt['enc_losses']

def time_to_cv(r):
    temp = np.where(r>(-200))[0]
    if len(temp)==0:
        return len(r)
    else: 
        return temp[0]

# %%
param = []
r_mean = []
r_std = []
enc_loss = []
for d in filter(lambda x:'Pendulum' in x,os.listdir(os.getcwd())):
    if os.path.exists(os.path.join(d,"model_parameters.txt")):
        with open(os.path.join(d,'model_parameters.txt')) as f:
            param.append(json.loads(f.read()))
        r_mean_, r_std_, enc_loss_ = load_reward(d)
        param[-1]['r_mean'] = np.array(r_mean_)
        param[-1]['r_std'] = np.array(r_std_)
        param[-1]['enc_loss'] = np.array(enc_loss_)
        
data = pd.DataFrame.from_dict(param)
data['name'] = [i.split('/')[-1] for i in data['save_dir']]

# %%
pd.set_option('display.max_columns', None)
data
# Out:
#     mode          env  seed  delay  stochastic_delays  max_delay  delay_proba  \
# 0  train     Pendulum     0     10              False         50          0.7
# 1  train  Pendulum-v0     0     10              False         50          0.7
# 2  train  Pendulum-v0     0     10              False         50          0.7
# 3  train  Pendulum-v0     0     10              False         50          0.7
#
#    force_stoch_env  steps_per_epoch  epochs  max_ep_len  gamma  delta  \
# 0             True             5000    1000         250   0.99  0.001
# 1            False             5000    1000         250   0.99  0.001
# 2            False             5000    1000         250   0.99  0.001
# 3            False             5000    1000         250   0.99  0.001
#
#    save_period  train_continue  test_episodes  test_steps epoch_load  v_hid  \
# 0          100           False             10         250       None     64
# 1          100           False             10         250       None     64
# 2          100           False             10         250       None     64
# 3          100           False             10         250       None     64
#
#    v_l  vf_lr  v_iters pi_activation  pi_hid  pi_l  damping_coeff  cg_iters  \
# 0    1   0.01        3       nn.ReLU      64     2            0.1        10
# 1    1   0.01        3       nn.ReLU      64     2            0.1        10
# 2    1   0.01        3       nn.ReLU      64     2            0.1        10
# 3    1   0.01        3       nn.ReLU      64     2            0.1        10
#
#    backtrack_iters  backtrack_coeff   lam  pretrain_epochs  \
# 0               10              0.8  0.97                2
# 1               10              0.8  0.97                2
# 2               10              0.8  0.97                2
# 3               10              0.8  0.97                2
#
#    epochs_belief_training  pretrain_steps  train_enc_iters  size_pred_buf  \
# 0                     300           10000                1         100000
# 1                     200           10000                1         100000
# 2                     200           10000                2         100000
# 3                     200           10000                2         100000
#
#    batch_size_pred  enc_lr  maf_lr  enc_dim  enc_heads  enc_l  enc_ff  \
# 0            10000   0.005   0.005       64          2      1       8
# 1            10000   0.010   0.010       64          2      1       8
# 2            10000   0.010   0.010       64          2      1       8
# 3            10000   0.010   0.010       64          2      1       8
#
#    enc_rescaling  enc_causal  enc_pred_to_pi  only_last_belief  convolutions  \
# 0          False        True           False             False         False
# 1          False        True           False             False         False
# 2          False        True           False             False         False
# 3          False        True           False             False         False
#
#     lstm  n_layers  hidden_size  n_blocks_maf  hidden_dim  hidden_dim_maf  \
# 0  False         3           16             5           4              16
# 1  False         3           16             5           4              16
# 2  False         3           16             5           4              16
# 3  False         3           16             5           8              16
#
#                                             save_dir  \
# 0     ./output/dtrpo/Pendulum-Results/Pendulum-run28
# 1  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 2  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
# 3  ./output/dtrpo/Pendulum-v0-Results/Pendulum-v0...
#
#                                               r_mean  \
# 0  [-1314.0713290993297, -1172.5814728671662, -11...
# 1  [-1651.253358335215, -1434.2494930050323, -149...
# 2  [-1651.253358335215, -1441.0748199457425, -151...
# 3  [-1674.6597073147873, -1457.0022640119987, -14...
#
#                                                r_std  \
# 0  [278.3906883608458, 369.3890987434081, 369.465...
# 1  [482.84896923808446, 368.9193173623081, 429.26...
# 2  [482.84896923808446, 365.65970601894776, 413.9...
# 3  [453.68238196655807, 362.57381480378484, 416.0...
#
#                                             enc_loss use_belief  \
# 0  [4.455460548400879, 4.561949253082275, 4.57046...        NaN
# 1  [4.452426910400391, 4.5694499015808105, 4.5531...       True
# 2  [4.402505874633789, 4.494041919708252, 4.46607...       True
# 3  [4.282286643981934, 4.3868913650512695, 4.4100...       True
#
#    stoch_mdp_param stoch_mdp_distrib                               name  \
# 0              NaN               NaN                     Pendulum-run28
# 1              1.0          Gaussian  Pendulum-v0-20-12-22_23_32_656352
# 2              1.0          Gaussian  Pendulum-v0-20-12-24_13_32_972251
# 3              1.0          Gaussian  Pendulum-v0-20-12-24_13_34_293193
#
#    max_mean_r  cv_speed
# 0 -704.985560      1000
# 1 -780.516364      1000
# 2 -699.393470      1000
# 3 -712.132075      1000

# %%
print('Different columns: \n')
for c in data.columns:
    a = data[c].values
    if not (a[0] == a).all():
        print('\t -  '+c+'\n')
# Out:
# Different columns:
#
# 	 -  env
#
# 	 -  force_stoch_env
#
# 	 -  epochs_belief_training
#
# 	 -  train_enc_iters
#
# 	 -  enc_lr
#
# 	 -  maf_lr
#
# 	 -  hidden_dim
#
# 	 -  save_dir
# C:\Users\pierr\Anaconda3\envs\dmdp\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3b21f94faf42> in <module>
#       2 for c in data.columns:
#       3     a = data[c].values
# ----> 4     if not (a[0] == a).all():
#       5         print('\t -  '+c+'\n')
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
for i, r in enumerate(data['r_mean']):
    m = np.argmax(r)
    print('{0:<40} - Max mean reward {1:<20} -  at epoch {2}'.format(data['name'][i],r[m],m))
    
data['max_mean_r'] = [max(r) for r in data['r_mean']]
data['cv_speed'] = [time_to_cv(r) for r in data['r_mean']]
# Out:
# Pendulum-run28                           - Max mean reward -704.9855597331358   -  at epoch 916
# Pendulum-v0-20-12-22_23_32_656352        - Max mean reward -780.5163639305408   -  at epoch 977
# Pendulum-v0-20-12-24_13_32_972251        - Max mean reward -699.3934704834362   -  at epoch 968
# Pendulum-v0-20-12-24_13_34_293193        - Max mean reward -712.1320752304051   -  at epoch 950

# %%
c
