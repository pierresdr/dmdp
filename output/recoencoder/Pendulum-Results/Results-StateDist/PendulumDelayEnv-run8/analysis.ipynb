# %%
import numpy as np
import pandas as pd
import pickle, os, re
import matplotlib.pyplot as plt
from matplotlib import cm
import math
import matplotlib.lines as mlines
import torch
import seaborn as sns

# %%
save_dir = os.getcwd()
visited_states = pickle.load(open(os.path.join(save_dir, 'visited_states.p'),"rb"))
visited_states = torch.cat(visited_states,0)

# %%
angle = np.arctan2(visited_states[:,1], visited_states[:,0])
data = np.hstack((visited_states[:,2].reshape(-1,1), angle.reshape(-1,1)))
df = pd.DataFrame(data, columns=["angle", "velocity"])

# %%
# sns.jointplot(x="angle", y="velocity", data=df)

# %%
sns.distplot(visited_states[:,2])

# %%
sns.distplot(angle)
